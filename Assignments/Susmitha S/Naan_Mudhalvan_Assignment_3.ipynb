# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/My Drive/nm3/House Price India.csv")
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
#checking null values
data.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
#performing descriptve statistic
data.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
#performing statistics for univarite analysis
data["Price"].mean()
# Out:
# 538932.2183310534

# %%
data["Price"].median()
# Out:
# 450000.0

# %%
data["Price"].std()
# Out:
# 367532.38080396695

# %%
data["Price"].value_counts()
# Out:
# 450000    114
# 350000    113
# 400000    104
# 375000    103
# 550000    102
#          ...
# 561600      1
# 856500      1
# 907687      1
# 307999      1
# 146000      1
# Name: Price, Length: 2901, dtype: int64

# %%
data.hist(column="Price",grid=False)
# Out:
# array([[<Axes: title={'center': 'Price'}>]], dtype=object)

# %%
sns.boxplot(data["Price"])
# Out:
# <Axes: >

# %%
sns.kdeplot(data["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
#bivarite analysis on house price data
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
y,x=data["Price"],data["grade of the house"]

# %%
pd.DataFrame(y,x)
# Out:
#                      Price
# grade of the house
# 10                  675000
# 8                   750000
# 8                   750000
# 9                   698000
# 8                   750000
# ...                    ...
# 7                   750000
# 7                   750000
# 6                   785000
# 6                   785000
# 6                   785000
#
# [14620 rows x 1 columns]

# %%
x.mean(),y.mean()
# Out:
# (7.682421340629275, 538932.2183310534)

# %%
x.median(),y.median()
# Out:
# (7.0, 450000.0)

# %%
x.std(),y.std(),x.max()
# Out:
# (1.1750327581231115, 367532.38080396695, 13)

# %%
plt.xlabel("grade of the house")
plt.ylabel("price")
plt.scatter(x,y)

# %%
sns.barplot(data,x="grade of the house",y="Price")
# Out:
# <Axes: xlabel='grade of the house', ylabel='Price'>

# %%
sns.lineplot(data,x="living area",y="Price",palette='bright',hue='grade of the house')
# Out:
# <Axes: xlabel='living area', ylabel='Price'>

# %%
#multivarite analysis on house price data
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
#Heatmap for each variable
# Create a correlation matrix
corr = data.corr()
fig, ax = plt.subplots(figsize=(15, 15))
# Create a heatmap
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
#pairplot for each variable
sns.pairplot(data)

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
#relational plot between price and area for different number of bedrooms
sns.relplot(data,x='living area',y='Price',palette='bright',height=4,kind='line',col='number of bedrooms')
# Out:
# <ipython-input-37-154a9b2a4ae4>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(data,x='living area',y='Price',palette='bright',height=4,kind='line',col='number of bedrooms')
